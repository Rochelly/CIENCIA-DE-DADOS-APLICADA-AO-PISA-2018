# %% [markdown]
# # Descrição dos dados - Questionário de professores - PISA 2018
# #### Serão utilizados os  dados informados pela OCDE,  sendo:
# * Questionário aplicado aos professores(https://www.oecd.org/pisa/publications/Brazil.zip)
# * Banco de dados do  questionário(https://webfs.oecd.org/pisa2018/SPSS_TCH_QQQ.zip)
# * Code book utilizado para mapear as perguntas em códigos utilizados no banco de dados(https://www.oecd.org/pisa/data/2018database/PISA2018_CODEBOOK.XLSX).

# %% [markdown]
# #### Importação das bibliotecas

# %%
import pandas as pd
import pyreadstat as ps

# %% [markdown]
# #### Importação do dataset de professores

# %%
professoresDF, infoProfessores=ps.read_sav('00-Bases-de-dados/Professores/CY07_MSU_TCH_QQQ.sav')

# %% [markdown]
# #### Verificando informações gerais sobre o dataset

# %%
professoresDF.describe()
# Out:
#              CNTRYID      CNTSCHID      CNTTCHID     TEACHERID         Region  \
# count  107367.000000  1.073670e+05  1.073670e+05  91190.000000  107367.000000
# mean      482.540324  4.825551e+07  4.825868e+07      4.694188   48256.795766
# std       271.547890  2.715644e+07  2.715653e+07      0.460753   27156.811300
# min         8.000000  8.000020e+05  8.000010e+05      4.000000     800.000000
# 25%       214.000000  2.140019e+07  2.140210e+07      4.000000   21400.000000
# 50%       591.000000  5.910005e+07  5.910072e+07      5.000000   59100.000000
# 75%       724.000000  7.240068e+07  7.241347e+07      5.000000   72413.000000
# max       840.000000  8.400018e+07  8.400378e+07      5.000000   84000.000000
#
#                 OECD  ADMINMODE      LANGTEST    TC001Q01NA    TC002Q01NA  \
# count  107367.000000   107367.0  93006.000000  90090.000000  90326.000000
# mean        0.444820        2.0    260.170150      1.368432     43.240374
# ...

# %% [markdown]
# #### Informações sobre as colunas

# %%
professoresDF.info(all)
#Segundo os dados de importação, o banco de dados do questionário aplicado aos professores possui 107367 entradas(linhas)
 #351 colunas.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107367 entries, 0 to 107366
# Data columns (total 352 columns):
#  #    Column            Dtype
# ---   ------            -----
#  0    CNTRYID           float64
#  1    CNT               object
#  2    CNTSCHID          float64
#  3    CNTTCHID          float64
#  4    TEACHERID         float64
#  5    CYC               object
#  6    NatCen            object
#  7    Region            float64
#  8    STRATUM           object
#  9    SUBNATIO          object
#  10   OECD              float64
#  11   ADMINMODE         float64
#  12   LANGTEST          float64
#  13   TC001Q01NA        float64
#  14   TC002Q01NA        float64
#  15   TC005Q01NA        float64
#  16   TC007Q01NA        float64
#  17   TC007Q02NA        float64
#  18   TC014Q01HA        float64
#  19   TC015Q01NA        float64
#  20   TC018Q01NA        float64
#  21   TC018Q01NB        float64
#  22   TC018Q02NA        float64
#  23   TC018Q02NB        float64
# ...

# %% [markdown]
# ####  Cabeçalho de todas as colunas

# %%
professoresDF.head(2)
# Out:
#    CNTRYID  CNT  CNTSCHID  CNTTCHID  TEACHERID   CYC  NatCen  Region  STRATUM  \
# 0      8.0  ALB  800057.0  800001.0        5.0  07MS  000800   800.0  ALB0203
# 1      8.0  ALB  800121.0  800002.0        5.0  07MS  000800   800.0  ALB0107
#
#   SUBNATIO  ...  FEEDBINSTR  TCATTIMM  GCTRAIN  TCMCEG  GCSELF  W_SCHGRNRABWT  \
# 0  0080000  ...         NaN       NaN      NaN     NaN     NaN        3.45567
# 1  0080000  ...         NaN       NaN      NaN     NaN     NaN        6.07334
#
#    W_FSTUWT_SCH_SUM             VER_DAT  BOOKID  test
# 0          93.30319    09MAY19:11:21:10     NaN   NaN
# 1          12.46632    09MAY19:11:21:10     NaN   NaN
#
# [2 rows x 352 columns]

# %% [markdown]
# #### Valores de respota de cada pergunta

# %%
#TC001
#  Pergunta: Você é do sexo feminino ou masculino?
#  é  uma resposta  númérica ,  sendo  1 para feminino e 2 para masculino
professoresDF['TC001Q01NA'].unique() # possiveis respostas
# Out:
# array([ 1.,  2., nan])

# %%
#TC002
# Pergunta: Qual é a sua idade?
# uma resposta numérica
professoresDF['TC002Q01NA'].unique() # valores respondidos
# Out:
# array([40., 26., 38., 42., 30., 56., 23., 43., 44., 58., 48., 34., 29.,
#        66., 51., 60., 47., 50., 36., 28., 31., nan, 35., 45., 39., 25.,
#        32., 46., 55., 61., 22., 52., 37., 59., 33., 53., 54., 65., 49.,
#        24., 63., 64., 41., 27., 57., 68., 20., 69., 62., 67., 70., 21.])

# %%
#TC186
# Pergunta: Em que país você nasceu?
# um resposta numérica, sendo 1 pais onde o teste está sem aplicado e 2 para outros  paises
professoresDF['TC186Q01HA'].unique() # valores respondidos
# Out:
# array([ 1., nan,  2.])

# %%
#TC005
# Pergunta: Qual é o seu status atual de emprego como professor?((Por favor, considere seu status de emprego nesta escola e para todos os seus demais empregos como professor juntos.)
# questão multipla escolha:
# o Valor 1 corresponde a : Tempo Integral(mais que 90% das horas completas)
# o Valor 2 corresponde a : Tempo Parcial(71-90% das horas completas) 
# o Valor 3 corresponde a : Tempo Parcial(50-70% das  horas completas)
# o Valor 4 corresponde a : Tempo parcial(Menos 50% das horas completas)
professoresDF['TC005Q01NA'].unique() # valores respondidos
# Out:
# array([ 1.,  3.,  4.,  2., nan])

# %%
#TC007
#Pergunta: Quantos anos de experiência de trabalho você possui? (Por favor, arredonde para anos inteiros sem se importar se você trabalhou por tempo parcial ou integral e mova o seletor para um número apropriado de anos.Se nenhuma opção se aplicar a você, selecione "0" (zero).)
# Essa questão se subdivide em duas:
# Tempo em que o professo trabalha na escola em que o teste está sendo aplicado(Ano(s) trabalhando como professor nesta escola):
professoresDF['TC007Q01NA'].unique()
# Tempo que o professor trabalha no total(Ano(s) trabalhando como professor no total)
professoresDF['TC007Q02NA'].unique()
# Out:
# array([10.,  5., 16.,  3., 34.,  1., 21.,  4., 28., 26., 32.,  6., 20.,
#        38., 14., 24., 17., 13.,  9.,  7., 15., nan, 12.,  8., 23., 42.,
#        11., 25., 30.,  2., 27., 36., 19., 31., 40., 33., 22., 37., 18.,
#        29., 35., 45., 39., 43., 41., 44.,  0., 50., 47., 49., 48., 46.])

# %%
#TC188
#Pergunta:Estudou em um país diferente do pais do teste ?
# Muitipla escolha  sendo:
# o Valor 1 corresponde a : Não
# o Valor 2 corresponde a : Sim, por menos de três meses
# o Valor 3 corresponde a : Sim, por três a doze meses
# o Valor 4 corresponde a : Sim, por mais de um ano
professoresDF['TC188Q01HA'].unique() # valores respondidos
# Out:
# array([ 1., nan,  3.,  4.,  2.])

# %%
#TC014
#Pergunta: Você completou uma licenciatura ou um programa de capacitação de professores?
# Muitipla escolha  sendo:
# o Valor 1 corresponde a : Sim, um programa de 1 ano ou menos
# o Valor 2 corresponde a : Sim, um programa de mais de 1 ano 
# o Valor 3 corresponde a : Não
professoresDF['TC014Q01HA'].unique() # valores respondidos
# Out:
# array([ 2.,  1.,  3., nan])

# %%
# TC015 - 
# Pergunta: Como você obteve suas qualificações docentes?
# Muitipla escolha  sendo:
# o Valor 1 corresponde a: Eu participei de um programa padrão de treinamento de professores em um <instituto educacional qualificado para educar ou treinar professores>.
# o Valor 2 corresponde a: Eu frequentei um programa de capacitação de professores em serviço.
# o Valor 3 corresponde a: Eu frequentei uma licenciatura ou programa de capacitação de professores baseada no trabalho.
# o Valor 4 corresponde a: Eu frequentei uma capacitação em outra profissão pedagógica. 
# o valor 5 corresponde a: outra
professoresDF['TC015Q01NA'].unique()
# Out:
# array([ 1.,  2.,  5., nan,  4.,  3.])

# %%
#TC018
# Pergunta: Qual dos tópicos abaixo estavam inclusos no seu curso de licenciatura ou programa de capacitação de professores ou em outra qualificação profissional e que você ensina en 1o e 2o ano do Ensino Médio no presente ano letivo?
#(Devido ao caráter internacional da pesquisa, tivemos que categorizar muitas das disciplinas de fato ensinadas nas escolas em categorias mais amplas. Se o
#nome exato de uma disciplina que você leciona não estiver na lista, marque a que melhor se encaixa ao que você ensina.)
#Leitura, escrita e litratura: leitura e escrita (e literatura) em língua materna, na língua da educação ou na língua original do país (região) como uma
#segunda língua (para não nativos); estudos linguisticos, oratória, literatura.
#Matemática: matemática, matemática com estatística, geometria, álgebra etc.
#Ciências: ciências naturais, física, ciência física, química, biologia, biologia humana, ciências da terra e do espaço, ciência ambiental, agricultura,
#horticultura/silvicultura.
#Tecnologia: orientação em tecnologia, incluindo tecnologia da informação, estudos do computador, construção/pesquisa, engenharia, eletrônica, design
#e gráfica, habilidades em digitação, processadores de texto, cursos em tecnologia ou design de tecnologias.
#Estudos Sociais: estudos sociais, estudos comunitários. Estudos contemporâneos, economia, estudos ambientais, geografia, história, humanidades,
#estudos legais, estudos do seu próprio país, ciências sociais, ética e filosofia
#Linguas Estrangeiras Modernas: línguas diferentes da língua da sua educação.
#Língua Clássica (por ex. Latim)
#Arte: arte, música, artes visuais, artes práticas, teatro, musical, fotografia, desenho, artesanato manual, bordado.
#Educação Física: educação física, ginástica, dança, saúde física.
#Religião e/ou ética: religião, história da religião, cultura da religião, ética.
#Habilidades práticas e profissionais: habilidades profissionais (preparação para uma profissão específica), técnicas, ciência doméstica, contabilidade,
#estudos em administração e negócios, educação para carreira, textil e vestuário, condução profissional, economia doméstica, cursos politécnicos, estudos
#de secretariado, turismo e hospitalidade, artesanato

# Essa pergunta se  subdivide em 22
# Pergunta Incluído na formação de professores, treinamento ou outra qualificação: Leitura, escrita e literatura
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q01NA'].unique()

#Pergunta: Ensino esse conteudo <série modal nacional para jovens de 15 anos> no atual ano escolar: Leitura, escrita e literatura
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q01NB'].unique()

#Pergunta:Incluído em meu curso de licenciatura ou em outro programa de qualificação profissional:Matemática.
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q02NA'].unique()

#Pergunta: Ensino esse conteudo <série modal nacional para jovens de 15 anos> no atual ano escolar: Matemática
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q02NB'].unique()

#Pergunta:Incluído em meu curso de licenciatura ou em outro programa de qualificação profissional: Ciencias
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q03NA'].unique()

#Pergunta:Ensino esse conteudo <série modal nacional para jovens de 15 anos> no atual ano escolar:Ciencias
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q03NB'].unique()

#Pergunta:Incluído em meu curso de licenciatura ou em outro programa de qualificação profissional:Tecnologia
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q04NA'].unique()

#Pergunta:Ensino esse conteudo <série modal nacional para jovens de 15 anos> no atual ano escolar:Tecnologia
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q04NB'].unique()

#Pergunta: Incluído em meu curso de licenciatura ou em outro programa de qualificação profissional: Estudos Sociais
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q05NA'].unique()

#Pergunta: Ensino esse conteudo <série modal nacional para jovens de 15 anos> no atual ano escolar: Estudos Sociais
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q05NB'].unique()

#Pergunta:Incluído em meu curso de licenciatura ou em outro programa de qualificação profissional:Línguas Estrangeiras Modernas
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q06NA'].unique()

#Pergunta:Ensino esse conteudo <série modal nacional para jovens de 15 anos> no atual ano escolar:Línguas Estrangeiras Modernas
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q06NB'].unique()

#Pergunta:Incluído em meu curso de licenciatura ou em outro programa de qualificação profissional:Língua Clássica (por ex. Latim)
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q07NA'].unique()

#Pergunta:Ensino esse conteudo <série modal nacional para jovens de 15 anos> no atual ano escolar:Língua Clássica (por ex. Latim)
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q07NB'].unique()

#Pergunta:Incluído em meu curso de licenciatura ou em outro programa de qualificação profissional:Artes
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q08NA'].unique()

#Pergunta:Ensino esse conteudo <série modal nacional para jovens de 15 anos> no atual ano escolar:Artes
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q08NB'].unique()

#Pergunta:Incluído em meu curso de licenciatura ou em outro programa de qualificação profissional:Educação Física
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q09NA'].unique()

#Pergunta:Ensino esse conteudo <série modal nacional para jovens de 15 anos> no atual ano escolar:Educação Física
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q09NB'].unique()

#Pergunta:Incluído em meu curso de licenciatura ou em outro programa de qualificação profissional:Religião e/ou ética
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q10NA'].unique()

#Pergunta:Ensino esse conteudo <série modal nacional para jovens de 15 anos> no atual ano escolar:Religião e/ou ética
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q10NB'].unique()

#Pergunta:Incluído em meu curso de licenciatura ou em outro programa de qualificação profissional:Habilidades práticas e profissionais
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q11NA'].unique()

#Pergunta:Ensino esse conteudo <série modal nacional para jovens de 15 anos> no atual ano escolar:Habilidades práticas e profissionais
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC018Q11NB'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
#TC045
#Pergunta: Alguns dos tópicos listados abaixo estavam inclusos em sua educação ou programa de treinamento ou outra qualificação profissional e em suas atividades de desenvolvimento profissional?
#Essa pergunta se  subdivide em outras sendo elas:


# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai:
# - Conhecimento e compreensão das áreas da minha matéria
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q01NA'].unique() #possiveis respostas


# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses: 
# - Conhecimento e compreensão das áreas da minha matéria
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q01NB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Competências pedagógicas no ensino das áreas da minha matéria
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q02NA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Competências pedagógicas no ensino das áreas da minha matéria
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q02NB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Conhecimento do currículo
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q03NA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Conhecimento do currículo
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q03NB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Práticas de avaliação de estudante
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q04NA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Práticas de avaliação de estudante
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q04NB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Habilidades na tecnologia de informação e comunicação para o ensino
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q05NA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Habilidades na tecnologia de informação e comunicação para o ensino
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q05NB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Comportamento do estudante e gestão de sala de aula
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q06NA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Comportamento do estudante e gestão de sala de aula
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q06NB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Gestão escolar e administração
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q07NA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Gestão escolar e administração
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q07NB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Introdução ao aprendizado individualizado
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q08NA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Introdução ao aprendizado individualizado
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q08NB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Ensino de alunos com necessidades especiais
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q09NA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Ensino de alunos com necessidades especiais
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q09NB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Ensino em um cenário multicultural e multilínguas
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q10NA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Ensino em um cenário multicultural e multilínguas
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q10NB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Ensino de habilidades interdisciplinares (ex: resolução de problemas, aprender a aprender)
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q11NA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Ensino de habilidades interdisciplinares (ex: resolução de problemas, aprender a aprender) 
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q11NB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Aconselhamento e orientação de carreira estudantil
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q12NA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Aconselhamento e orientação de carreira estudantil
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q12NB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Avaliação interna ou auto-avaliação das escolas
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q13NA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Avaliação interna ou auto-avaliação das escolas
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q13NB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Usos dos resultados da avaliação
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q14NA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Usos dos resultados da avaliação
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q14NB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Cooperação pai-professor
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q15NA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Cooperação pai-professor
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q15NB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Ensino de língua estrangeira
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q16HA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Ensino de língua estrangeira
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q16HB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Comunicação com pessoas de diferentes culturas ou países
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q17HA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Comunicação com pessoas de diferentes culturas ou países
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q17HB'].unique() #possiveis respostas

# Pergunta:Incluso na minha educação ou programa de treinamento ou outras qualificações profissionai: 
# - Ensino sobre equidade e diversidade
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q18HA'].unique() #possiveis respostas

# Pergunta:Incluso nas atividades de desenvolvimento profissional durante os últimos 12 meses
# - Ensino sobre equidade e diversidade
# Um check box, onde:
# 0 - Não marcado
# 1-  Marcado
professoresDF['TC045Q18HB'].unique() #possiveis respostas
# Out:
# array([ 0.,  1., nan])

# %%
#TC206
# Pergunta: As informações a seguir refletem sua educação e formação como professor?
# Essa  pergunta se divide em 4 sendo elas:

# Pergunta: Comunicação intercultural faz parte da sua formação?
# 1 - sim
# 2 - não
professoresDF['TC206Q01HA'].unique() #possiveis respostas

# Pergunta: Estratégias de resolução de conflitos faz parte da sua formação?
# 1 - sim
# 2 - não
professoresDF['TC206Q02HA'].unique() #possiveis respostas

# Pergunta: O papel que a educação pode desempenhar em confrontar a discriminação em todas as suas formas faz parte da sua formação?
# 1 - sim
# 2 - não
professoresDF['TC206Q03HA'].unique() #possiveis respostas

# Pergunta: Você estudou técnicas e abordagens de ensino culturalmente sensíveis?
# 1 - sim
# 2 - não
professoresDF['TC206Q04HA'].unique() #possiveis respostas


# Pergunta: Faz parte de sua formação questões relacionadas ao ensino em salas de aula multiculturais?
# 1 - sim
# 2 - não
professoresDF['TC206Q05HA'].unique() #possiveis respostas
# Out:
# array([nan])

# %%
#TC185
#Pergunta: Para cada uma das áreas listadas abaixo, indique o grau da sua necessidade atual de formação continuada.
#Essa quetão  se divide em 18
# Todas com  as seguintes  possiveis respostas 
# 1 - Nenhuma necessidade
# 2 - Pouca necessidade
# 3 - Necessidade moderada
# 4 - Grande necessidade


#Pergunta:Conhecimento e compreensão da(s) disciplina(s) que ministro.
professoresDF['TC185Q01HA'].unique() #possiveis respostas

#Pergunta:Competências pedagógicas na(s) disciplina(s) que ministro.
professoresDF['TC185Q02HA'].unique() #possiveis respostas

#Pergunta:Conhecimento da estrutura curricular.
professoresDF['TC185Q03HA'].unique() #possiveis respostas


#Pergunta:Práticas de avaliação de estudantes.
professoresDF['TC185Q04HA'].unique() #possiveis respostas

#Pergunta: Competências em Tecnologias da Informação e da Comunicação (TIC) como auxílio ao ensino.
professoresDF['TC185Q05HA'].unique() #possiveis respostas

#Pergunta:Gestão de sala de aula e comportamento de estudantes.
professoresDF['TC185Q06HA'].unique() #possiveis respostas

#Pergunta:Gestão escolar e administração
professoresDF['TC185Q07HA'].unique() #possiveis respostas

#Pergunta:Abordagens pedagógicas individualizadas.
professoresDF['TC185Q08HA'].unique() #possiveis respostas

#Pergunta:Ensino a estudantes com necessidades especiais.
professoresDF['TC185Q09HA'].unique() #possiveis respostas

#Pergunta:Ensino em um cenário multicultural ou plurilíngue.
professoresDF['TC185Q10HA'].unique() #possiveis respostas

#Pergunta:Ensino de competências transversais (resolução de problemas, métodos de aprendizagem).
professoresDF['TC185Q11HA'].unique() #possiveis respostas

#Pergunta:Aconselhamento e orientação vocacional.
professoresDF['TC185Q12HA'].unique() #possiveis respostas

#Pergunta:Avaliação interna ou autoavaliação das escolas.
professoresDF['TC185Q13HA'].unique() #possiveis respostas

#Pergunta:Usos dos resultados da avaliação.
professoresDF['TC185Q14HA'].unique() #possiveis respostas

#Pergunta:Cooperação entre pais e professores.
professoresDF['TC185Q15HA'].unique() #possiveis respostas

#Pergunta:Ensino de uma segunda língua.
professoresDF['TC185Q16HA'].unique() #possiveis respostas

#Pergunta:Comunicação com pessoas de diferentes culturas ou países.
professoresDF['TC185Q17HA'].unique() #possiveis respostas
# Out:
# array([nan])

# %%
#TC021
#Pergunta:Você é solicitado a participar de atividades voltadas para o desenvolvimento profissional?
#1 - sim
#2 - não
professoresDF['TC021Q01NA'].unique() #possiveis respostas
# Out:
# array([ 1.,  2., nan])

# %%
#TC193
#Pergunta: Nos últimos 12 meses, você participou de alguma das seguintes atividades de desenvolvimento profissional?
# Divididos em 5 perguntas:
#Valore possiveis de serem respondidos:
# 1 - sim 
# 2 - não

#Pergunta: Cursos/workshops (p. ex., questões de conteúdo ou metodologia e/ou outros tópicos relacionados à Educação).
professoresDF['TC193Q01HA'].unique() #possiveis respostas

#Pergunta: Congressos ou seminários em Educação (nos quais professores e/ou pesquisadores apresentam seus resultados e discutem assuntos educacionais).
professoresDF['TC193Q02HA'].unique() #possiveis respostas


#Pergunta: Visitas de observação a outras escolas.
professoresDF['TC193Q03HA'].unique() #possiveis respostas


#Pergunta: Visitas de observação a empresas, órgãos públicos ou organizações não governamentais.
professoresDF['TC193Q04HA'].unique() #possiveis respostas


#Pergunta: Cursos de formação continuada oferecidos pela escola em empresas, órgãos públicos ou organizações não governamentais.
professoresDF['TC193Q05HA'].unique() #possiveis respostas
# Out:
# array([ 2.,  1., nan])

# %%
#TC020
#Pergunta: Durante os últimos 12 meses você participou de alguma das seguintes atividades?
# Divididos em 6 perguntas:
#Valore possiveis de serem respondidos:
# 1 - sim 
# 2 - não


#Pergunta:Programa de Qualificação (por ex. aperfeiçoamento ou especialização)
professoresDF['TC020Q01NA'].unique() #possiveis respostas

#Pergunta: Participação em uma rede de professores formada especificamente  para o desenvovlimento profissional de professores
professoresDF['TC020Q02NA'].unique() #possiveis respostas

#Pergunta: Pesquisa colaborativa ou individual em um tópico de seu interesse profissional
professoresDF['TC020Q03NA'].unique() #possiveis respostas

#Pergunta: Orientação e/ou observação e treinamento como parte da organização formal da escola
professoresDF['TC020Q04NA'].unique() #possiveis respostas

#Pergunta: Leituras profissionais (por ex. artigos científicos, trabalhos acadêmicos, teses etc)
professoresDF['TC020Q05NA'].unique() #possiveis respostas

#Pergunta: Reuniões informais com seus colegas sobre como melhorar seu  ensino
professoresDF['TC020Q06NA'].unique() #possiveis respostas
# Out:
# array([ 1., nan,  2.])

# %%
#TC175
#Pergunta:Quantas horas por semana você passa lendo para o seu trabalho (artigos, revistas, livros, manuais, sites) fora da sala de aula?
# Valores possiveis a serem respondidos:
# 1 - Menos de 1 hora por semana.
# 2 - De 1 a 3 horas por semana.
# 3 - De 4 a 6 horas por semana.
# 4 - Mais de 6 horas por semana.
professoresDF['TC175Q01HA'].unique() #possiveis respostas
# Out:
# array([ 3.,  4.,  2., nan,  1.])

# %%
#TC198
#Pergunta: Gostaríamos de saber como você se sente em relação ao seu emprego. Até que ponto você concorda ou discorda das afirmações a seguir?
#Valores  possiveis a sereme respondidos:
# 1 - Discordo totalmente
# 2 - Discordo
# 3 - Concordo
# 4 -Concordo totalmente
# Essa questão contém  outras perguntas, sendo  elas:

# Pergunta: As vantagens em ser professor claramente superam as desvantagens.
professoresDF['TC198Q01HA'].unique() #possiveis respostas

# Pergunta: Se eu pudesse escolher novamente, ainda escolheria trabalhar como professor.
professoresDF['TC198Q02HA'].unique() #possiveis respostas

# Pergunta: Gostaria de mudar para outra escola se isso fosse possível.
professoresDF['TC198Q03HA'].unique() #possiveis respostas

# Pergunta: Eu me arrependo de ter optado pelo magistério.
professoresDF['TC198Q04HA'].unique() #possiveis respostas

# Pergunta: Gosto de trabalhar nesta escola.
professoresDF['TC198Q05HA'].unique() #possiveis respostas

# Pergunta: Eu me pergunto se teria sido melhor escolher outra profissão.
professoresDF['TC198Q06HA'].unique() #possiveis respostas

# Pergunta: Recomendaria minha escola como um bom lugar para trabalhar.
professoresDF['TC198Q07HA'].unique() #possiveis respostas

# Pergunta: Acho que a profissão de professor é valorizada pela sociedade.
professoresDF['TC198Q08HA'].unique() #possiveis respostas

# Pergunta: Estou satisfeito(a) com meu desempenho nesta escola.
professoresDF['TC198Q09HA'].unique() #possiveis respostas

# Pergunta: No geral, estou satisfeito(a) com meu emprego.
professoresDF['TC198Q10HA'].unique() #possiveis respostas
# Out:
# array([ 4.,  3., nan,  1.,  2.])

# %%
#TC199
#Pergunta:Nas suas aulas, até que ponto você pode fazer o seguinte?
#Valores  possiveis a sereme respondidos:
# 1 - Nem um pouco
# 2 - Até certo ponto
# 3 - Consideravelmente
# 4 - Muito
# Essa questão contém  outras perguntas, sendo  elas:

# Pergunta: Fazer os estudantes acreditarem que podem ter bons resultados escolares.
professoresDF['TC199Q01HA'].unique() #possiveis respostas

# Pergunta: Ajudar meus estudantes a valorizar o aprendizado.
professoresDF['TC199Q02HA'].unique() #possiveis respostas

# Pergunta: Elaborar boas questões para meus estudantes.
professoresDF['TC199Q03HA'].unique() #possiveis respostas

# Pergunta: Controlar problemas comportamentais em sala de aula.
professoresDF['TC199Q04HA'].unique() #possiveis respostas

# Pergunta: Motivar os estudantes com baixo interesse nos trabalhos escolares.
professoresDF['TC199Q05HA'].unique() #possiveis respostas

# Pergunta: Deixar claras minhas expectativas sobre o comportamento dos estudantes.
professoresDF['TC199Q06HA'].unique() #possiveis respostas

# Pergunta: Ajudar os estudantes a desenvolver o pensamento crítico.
professoresDF['TC199Q07HA'].unique() #possiveis respostas

# Pergunta: Fazer com que os estudantes respeitem as regras da sala de aula.
professoresDF['TC199Q08HA'].unique() #possiveis respostas

# Pergunta: Acalmar um estudante com problemas de comportamento ou barulhento.
professoresDF['TC199Q09HA'].unique() #possiveis respostas

# Pergunta: Usar diversas estratégias de avaliação.
professoresDF['TC199Q10HA'].unique() #possiveis respostas

# Pergunta: Oferecer uma explicação alternativa, quando os estudantes estão confusos.
professoresDF['TC199Q11HA'].unique() #possiveis respostas

# Pergunta: Utilizar estratégias educacionais alternativas na sala de aula.
professoresDF['TC199Q12HA'].unique() #possiveis respostas
# Out:
# array([ 4., nan,  2.,  3.,  1.])

# %%
#TC046
#Pergunta: Em média, com que frequência você executa as seguintes atividades nessa escola?
#Valores  possiveis a sereme respondidos:
# 1 - Nunca
# 2 - Uma vez por ano ou menos
# 3 - 2 a 4 vezes por ano
# 4 - 5 a 10 vezes por ano
# 5 - 1 a 3 vezes por mês
# 6 - Uma vez por semana ou mais
## Essa questão contém  outras perguntas, sendo  elas:

#Pergunta:Trocar materiais de ensino com colegas
professoresDF['TC046Q04NA'].unique() #possiveis respostas


#Pergunta: Empenhar-se em discussões sobre o  desenvolvimento do aprendizado de alunos específicos
professoresDF['TC046Q05NA'].unique() #possiveis respostas


#Pergunta:Trabalhar com outros professores na minha escola para assegurar padrões comuns nas provas para avaliar o progresso do aluno 
professoresDF['TC046Q06NA'].unique() #possiveis respostas 

#Pergunta:Frequentar as conferências da equipe
professoresDF['TC046Q07NA'].unique() #possiveis respostas
# Out:
# array([ 4.,  6.,  5.,  3., nan,  2.,  1.])

# %%
#TC028
#A capacidade da sua escola em fornecer uma boa educação é prejudicada por algumas das seguintes questões?
#Valores  possiveis a sereme respondidos:
# 1 - Nem um pouco
# 2 - Pouco
# 3 - Até certo ponto
# 4 - Muito

#Pergunta:Corpo docente em quantidade insuficiente.
professoresDF['TC028Q01NA'].unique() #possiveis respostas

#Pergunta:Qualificação inadequada ou insuficiente do corpo docente.
professoresDF['TC028Q02NA'].unique() #possiveis respostas

#Pergunta:Ausência de pessoal de apoio.
professoresDF['TC028Q03NA'].unique() #possiveis respostas

#Pergunta:Qualificação inadequada ou insuficiente do pessoal de apoio.
professoresDF['TC028Q04NA'].unique() #possiveis respostas

#Pergunta:Ausência de material educacional (por ex. livros didáticos, equipamentos tecnológicos, biblioteca ou materiais de laboratório).
professoresDF['TC028Q05NA'].unique() #possiveis respostas

#Pergunta:Qualidade inadequada ou insuficiente do material educacional (por ex. livros didáticos, equipamentos tecnológicos, biblioteca ou materiais de laboratório).
professoresDF['TC028Q06NA'].unique() #possiveis respostas

#Pergunta:Ausência de infraestrutura física (por ex. prédios, áreas de convivência, aquecimento/refrigeração, sistemas de iluminação ou acústicos).
professoresDF['TC028Q07NA'].unique() #possiveis respostas

#Pergunta:Qualidade inadequada ou insuficiente de infraestrutura física (por ex. prédios, áreas de convivência, aquecimento/refrigeração, sistemas de iluminação ou acústicos).
professoresDF['TC028Q08NA'].unique() #possiveis respostas
# Out:
# array([ 3.,  2.,  1., nan,  4.])

# %%
#TC152
#Pergunta:Até que ponto você concorda ou discorda das seguintes afirmações?
#Valores  possiveis a sereme respondidos:
# 1 - Discordo totalmente
# 2 - Discordo
# 3 - Concordo
# 4 -Concordo totalmente
# Essa questão contém  outras perguntas, sendo  elas:

#Pergunta:Todo professor deveria receber capacitação para ensinar interpretação de texto.
professoresDF['TC152Q01HA'].unique() #possiveis respostas

#Pergunta:Todo professor tem a responsabilidade de aperfeiçoar as habilidades de interpretação de texto dos estudantes.
professoresDF['TC152Q02HA'].unique() #possiveis respostas

#Pergunta:Sei como diagnosticar problemas de interpretação de texto dos estudantes.
professoresDF['TC152Q03HA'].unique() #possiveis respostas

#Pergunta:Confio muito na minha capacidade de ensinar estratégias de interpretação de texto.
professoresDF['TC152Q04HA'].unique() #possiveis respostas
# Out:
# array([ 4.,  3., nan,  2.,  1.])

# %%
#TC155
#Pergunta:Com que frequência você ensina os seguintes aspectos relativos à interpretação de texto nas suas aulas?
#Valores  possiveis a sereme respondidos:
# 1 - Nunca ou quase nunca
# 2 - Em algumas aulas
# 3 - Em muitas aulas
# 4 - Em todas as aulas ou quase todas as aulas

# Essa questão contém  outras perguntas, sendo  elas:


#Pergunta:Estratégias de escrita de resumo.
professoresDF['TC155Q02HA'].unique() #possiveis respostas

#Pergunta:Relacionar os textos com o conhecimento prévio sobre o assunto.
professoresDF['TC155Q03HA'].unique() #possiveis respostas

#Pergunta:Monitorar a compreensão.
professoresDF['TC155Q04HA'].unique() #possiveis respostas

#Pergunta:Adaptar o modo de ler em função dos objetivos.
professoresDF['TC155Q05HA'].unique() #possiveis respostas

#Pergunta:Avaliar a credibilidade das informações disponíveis na internet.
professoresDF['TC155Q06HA'].unique() #possiveis respostas

#Pergunta:Buscar e selecionar informações relevantes na internet.
professoresDF['TC155Q07HA'].unique() #possiveis respostas
# Out:
# array([ 2.,  3.,  4.,  1., nan])

# %%
#TC166
#Pergunta:Você já ensinou algum dos itens abaixo nas suas aulas?
#Valores  possiveis a sereme respondidos:
# 1 - sim
# 2 - não
# Essa questão contém  outras perguntas, sendo  elas:

#Pergunta: Como utilizar palavras-chave em mecanismos de busca como Google©, Bing® etc.
professoresDF['TC166Q01HA'].unique() #possiveis respostas

#Pergunta:Como decidir sobre a credibilidade de informações encontradas na internet.
professoresDF['TC166Q02HA'].unique() #possiveis respostas

#Pergunta:Como comparar diferentes páginas da internet e decidir qual informação é mais apropriada para o trabalho escolar dos estudantes.
professoresDF['TC166Q03HA'].unique() #possiveis respostas

#Pergunta:Compreender as consequências de disponibilizar publicamente informações pessoais on-line no Facebook©, Instagram© etc.
professoresDF['TC166Q04HA'].unique() #possiveis respostas

#Pergunta: Como utilizar a breve descrição sob os links na lista de resultados de uma busca.
professoresDF['TC166Q05HA'].unique() #possiveis respostas

#Pergunta: Como detectar se uma informação é subjetiva ou tendenciosa.
professoresDF['TC166Q06HA'].unique() #possiveis respostas

#Pergunta: Como detectar e-mails de phishing ou spam.
professoresDF['TC166Q07HA'].unique() #possiveis respostas
# Out:
# array([ 2.,  1., nan])

# %%
#TC164
#Pergunta: Neste ano letivo, quantas páginas tinha o texto mais longo que seus estudantes do 1º e 2º ano do Ensino Médio tiveram de ler para suas aulas?
#Valores  possiveis a sereme respondidos:
# 1 - Uma página ou menos.
# 2 - De 2 a 10 páginas.
# 3 - De 11 a 50 páginas.
# 4 - De 51 a 100 páginas.
# 5 - De 101 a 500 páginas.
# 6 - Mais de 500 páginas.
professoresDF['TC164Q01HA'].unique() #possiveis respostas
# Out:
# array([ 2.,  4.,  5.,  6.,  3.,  1., nan])

# %%
#TC207
#Pergunta:Na(s) sua(s) disciplina(s), você favorece a aquisição das seguintes competências?
#Valores  possiveis a sereme respondidos:
# 1 - sim
# 2 - não
# Essa questão contém  outras perguntas, sendo  elas:

#Pergunta: Comunicação com pessoas de diferentes culturas ou países.
professoresDF['TC207Q01HA'].unique() #possiveis respostas

#Pergunta: Conhecimento sobre diferentes culturas.
professoresDF['TC207Q02HA'].unique() #possiveis respostas

#Pergunta: Receptividade a pessoas de outras origens culturais.
professoresDF['TC207Q03HA'].unique() #possiveis respostas

#Pergunta: Respeito à diversidade cultural.
professoresDF['TC207Q04HA'].unique() #possiveis respostas

#Pergunta: Línguas estrangeiras.
professoresDF['TC207Q05HA'].unique() #possiveis respostas

#Pergunta: Pensamento crítico.
professoresDF['TC207Q06HA'].unique() #possiveis respostas
# Out:
# array([nan])

# %%
#TC178
#Pergunta:Na(s) sua(s) disciplina(s), você aborda as seguintes tendências e desafios mundiais?
#Valores  possiveis a sereme respondidos:
# 1 - sim
# 2 - não
# Essa questão contém  outras perguntas, sendo  elas:

#Pergunta:Mudança climática e aquecimento global.
professoresDF['TC178Q01HA'].unique() #possiveis respostas

#Pergunta:Saúde global (p. ex., epidemias).
professoresDF['TC178Q02HA'].unique() #possiveis respostas

#Pergunta:Migração (deslocamentos de pessoas).
professoresDF['TC178Q04HA'].unique() #possiveis respostas

#Pergunta:Conflitos internacionais.
professoresDF['TC178Q07HA'].unique() #possiveis respostas

#Pergunta:Fome ou desnutrição nas diferentes partes do mundo.
professoresDF['TC178Q08HA'].unique() #possiveis respostas

#Pergunta:Causas da pobreza.
professoresDF['TC178Q09HA'].unique() #possiveis respostas

#Pergunta:Igualdade entre homens e mulheres em diferentes partes do mundo.
professoresDF['TC178Q12HA'].unique() #possiveis respostas
# Out:
# array([nan])

# %%
#TC169
#Pergunta:Com que frequência você tem usado as seguintes ferramentas de ensino neste ano letivo?
#Valores  possiveis a sereme respondidos:
# 1 - Nunca
# 2 - Em algumas aulas
# 3 - Em muitas aulas
# 4 - Em todas as aulas ou quase todas as aulas
# Essa questão contém  outras perguntas, sendo  elas:

#Pergunta:Softwares de instrução ou programas de exercícios.
professoresDF['TC169Q01HA'].unique() #possiveis respostas

#Pergunta:Jogos digitais para aprendizado.
professoresDF['TC169Q02HA'].unique() #possiveis respostas

#Pergunta:Processadores de textos ou softwares de apresentações (p. ex., Microsoft  Word ®, PowerPoint®).
professoresDF['TC169Q03HA'].unique() #possiveis respostas

#Pergunta:Planilhas (p. ex., Microsoft Excel®).
professoresDF['TC169Q04HA'].unique() #possiveis respostas

#Pergunta:Ferramentas de produção multimídia (p. ex., captura e tratamento de mídias,produção Web).
professoresDF['TC169Q05HA'].unique() #possiveis respostas

#Pergunta:Software de mapa conceitual (p. ex., Cmap®, Xmind®).
professoresDF['TC169Q06HA'].unique() #possiveis respostas

#Pergunta:Registro de dados e ferramentas de monitoramento.
professoresDF['TC169Q07HA'].unique() #possiveis respostas

#Pergunta:Softwares de simulações e modelagem.
professoresDF['TC169Q08HA'].unique() #possiveis respostas

#Pergunta:Redes sociais (p. ex., Facebook©, Twitter®).
professoresDF['TC169Q09HA'].unique() #possiveis respostas

#Pergunta:Softwares de comunicação (p. ex., e-mail, blogs).
professoresDF['TC169Q10HA'].unique() #possiveis respostas

#Pergunta:Recursos de informações no computador (p. ex., sites, wikis, enciclopédias).
professoresDF['TC169Q11HA'].unique() #possiveis respostas

#Pergunta:Recursos de aprendizado digital interativo (p. ex., objetos de aprendizagem).
professoresDF['TC169Q12HA'].unique() #possiveis respostas

#Pergunta:Softwares de gráfico ou desenho.
professoresDF['TC169Q13HA'].unique() #possiveis respostas

#Pergunta:Portfolios eletrônicos.
professoresDF['TC169Q14HA'].unique() #possiveis respostas
# Out:
# array([ 1.,  2., nan,  3.,  4.])

# %%
#TC184
#PerguntaSua escola tem uma política em relação ao uso de dispositivos eletrônicos para o ensino?
#Valores  possiveis a sereme respondidos:
# 1 - sim
# 2 - não TC184Q01HA
professoresDF['TC184Q01HA'].unique() #possiveis respostas
# Out:
# array([ 1.,  2., nan])

# %%
#TC169
#Pergunta:Com que frequência você tem usado as seguintes ferramentas de ensino neste ano letivo?
#Valores  possiveis a sereme respondidos:
# 1 - Nunca ou quase nunca
# 2 - Algumas aulas
# 3 - Muitas aulas
# 4 - Toda aula ou quase todas as aulas
# Essa questão contém  outras perguntas, sendo  elas:


#Pergunta: Eu desenvolvo e aplico minhas próprias avaliações.
professoresDF['TC054Q01NA'].unique() #possiveis respostas


#Pergunta:Eu aplico um teste padronizado.
professoresDF['TC054Q02NA'].unique() #possiveis respostas


#Pergunta:Eu faço os alunos responderem questões em frente da turma.
professoresDF['TC054Q03NA'].unique() #possiveis respostas


#Pergunta:Eu providencio retornos escritos dos trabalhos dos alunos juntamente com  uma nota, expressa em número ou letra.
professoresDF['TC054Q04NA'].unique() #possiveis respostas


#Pergunta:Eu permito que os próprios alunos julguem seus progressos.
professoresDF['TC054Q05NA'].unique() #possiveis respostas


#Pergunta: Eu observo os alunos quando estão trabalhando nas tarefas particulares e providencio feedback imediato.
professoresDF['TC054Q06NA'].unique() #possiveis respostas


#Pergunta: Eu coleto dados das tarefas de classe ou dever de casa.
professoresDF['TC054Q07NA'].unique() #possiveis respostas
# Out:
# array([ 3., nan,  4.,  2.,  1.])

# %%
#TC192
#Pergunta:Com que frequência as seguintes situações ocorrem nas suas aulas?
#Valores  possiveis a sereme respondidos:
# 1 - Nunca ou quase nunca
# 2 - Algumas aulas
# 3 - Muitas aulas
# 4 - Toda aula ou quase todas as aulas

# Essa questão contém  outras perguntas, sendo  elas:


#Pergunta: Informo aos meus estudantes como eles estão se saindo na minha disciplina.
professoresDF['TC192Q01HA'].unique() #possiveis respostas

#Pergunta: Informo aos meus estudantes seus pontos fortes na minha disciplina.
professoresDF['TC192Q02HA'].unique() #possiveis respostas

#Pergunta: Informo aos meus estudantes em quais áreas eles ainda podem  melhorar.
professoresDF['TC192Q03HA'].unique() #possiveis respostas

#Pergunta: Informo aos meus estudantes como eles podem melhorar seu desempenho.
professoresDF['TC192Q04HA'].unique() #possiveis respostas

#Pergunta: Dou conselhos aos estudantes sobre como atingir seus objetivos de aprendizagem.
professoresDF['TC192Q05HA'].unique() #possiveis respostas
# Out:
# array([ 3.,  2., nan,  4.,  1.])

# %%
#TC192
#Pergunta: Como você julga sua competência para ensinar em uma sala com alto grau de diversidade cultural e étnica?
#Valores  possiveis a sereme respondidos:
# 1 - Discordo totalmente
# 2 - Discordo
# 3 - Concordo
# 4 - Concordo  totalmente


# Essa questão contém  outras perguntas, sendo  elas:


#Pergunta: Eu consigo gerir os desafios de uma sala de aula multicultural.
professoresDF['TC209Q01HA'].unique() #possiveis respostas


#Pergunta: Eu consigo adaptar minha aula à diversidade cultural dos estudantes.
professoresDF['TC209Q02HA'].unique() #possiveis respostas

#Pergunta: Eu consigo fazer com que estudantes oriundos ou não de migração trabalhem juntos.
professoresDF['TC209Q05HA'].unique() #possiveis respostas

#Pergunta: Eu consigo estimular maior compreensão das diferenças culturais entre os estudantes.
professoresDF['TC209Q06HA'].unique() #possiveis respostas

#Pergunta: Eu consigo contribuir para reduzir os estereótipos étnicos entre os estudantes.
professoresDF['TC209Q09HA'].unique() #possiveis respostas
# Out:
# array([nan])

# %%
#TC209
#Pergunta:Como você julga sua competência para ensinar em uma sala com alto grau de diversidade cultural e étnica?
#Valores  possiveis a sereme respondidos:
# 1 - Discordo totalmente
# 2 - Discordo
# 3 - Concordo
# 4 - Concordo  totalmente




# Essa questão contém  outras perguntas, sendo  elas:


#Pergunta: Eu consigo gerir os desafios de uma sala de aula multicultural.
professoresDF['TC209Q01HA'].unique() #possiveis respostas

#Pergunta: Eu consigo adaptar minha aula à diversidade cultural dos estudantes.
professoresDF['TC209Q02HA'].unique() #possiveis respostas

#Pergunta: Eu consigo fazer com que estudantes oriundos ou não de migração trabalhem juntos.
professoresDF['TC209Q05HA'].unique() #possiveis respostas

#Pergunta: Eu consigo estimular maior compreensão das diferenças culturais entre os estudantes.
professoresDF['TC209Q06HA'].unique() #possiveis respostas

#Pergunta: Eu consigo contribuir para reduzir os estereótipos étnicos entre os estudantes.
professoresDF['TC209Q09HA'].unique() #possiveis respostas
# Out:
# array([nan])

# %%
#TC208
#Pergunta:Até que ponto as seguintes opiniões são partilhadas pelos professores da sua escola?
#Valores  possiveis a sereme respondidos:
# 1 - Opinião partilhada  por nenhum ou quase nenhum professor
# 2 - Opinião partilhada por alguns professores
# 3 - Opinião partilhada por muitos professores
# 4 - Opinião partilhada por todos ou quase todos os professores

# Essa questão contém  outras perguntas, sendo  elas:


#Pergunta: É importante que os estudantes aprendam que pessoas de outras culturas podem ter valores diferentes.
professoresDF['TC208Q02HA'].unique() #possiveis respostas

#Pergunta: O respeito a outras culturas é algo que os estudantes devem aprender desde cedo.
professoresDF['TC208Q03HA'].unique() #possiveis respostas

#Pergunta: Na sala de aula, é importante que estudantes de diferentes origens reconheçam as semelhanças que existem entre eles
professoresDF['TC208Q07HA'].unique() #possiveis respostas

#Pergunta: Quando ocorrem conflitos entre estudantes de diferentes origens, eles devem ser estimulados a resolver a questão buscando um consenso.
professoresDF['TC208Q08HA'].unique() #possiveis respostas
# Out:
# array([nan])

# %%
#TC196
#Pergunta:Cada vez mais as pessoas se mudam de um país para outro. Até que ponto você concorda com as seguintes afirmações em relação a imigrantes?
#Valores  possiveis a sereme respondidos:
# 1 - Discordo totalmente
# 2 - Discordo
# 3 - Concordo
# 4 - Concordo  totalmente




# Essa questão contém  outras perguntas, sendo  elas:


#Pergunta: Filhos de imigrantes devem ter as mesmas oportunidades de educação que as oferecidas às crianças do país
professoresDF['TC196Q02HA'].unique() #possiveis respostas

#Pergunta: Imigrantes que moram num país há muitos anos devem poder votar nas eleições.
professoresDF['TC196Q03HA'].unique() #possiveis respostas


#Pergunta: Imigrantes devem ter a oportunidade de manter seus próprios costumes e estilos de  vida.
professoresDF['TC196Q04HA'].unique() #possiveis respostas

#Pergunta: Imigrantes devem ter os mesmos direitos que todos têm no país.
professoresDF['TC196Q05HA'].unique() #possiveis respostas
# Out:
# array([nan])

# %%
#TC176
#Pergunta:Com que frequência você se dedica às seguintes atividades de leitura?
#Valores  possiveis a sereme respondidos:
# 1 - Não sei o que é isto. 
# 2 - Nunca ou quase nunca.
# 3 - Várias vezes por mês.
# 4 - Várias vezes por semana.
# 5 - Várias vezes por dia.

# Essa questão contém  outras perguntas, sendo  elas:

#Pergunta: Ler e-mails.
professoresDF['TC176Q01HA'].unique() #possiveis respostas

#Pergunta: Conversar on-line (p. ex., Whatsapp®, Facebook®).
professoresDF['TC176Q02HA'].unique() #possiveis respostas

#Pergunta: Ler notícias on-line.
professoresDF['TC176Q03HA'].unique() #possiveis respostas

#Pergunta: Buscar informações on-line para saber mais sobre um assunto específico.
professoresDF['TC176Q05HA'].unique() #possiveis respostas

#Pergunta: Participar de grupos de discussão ou fóruns on-line.
professoresDF['TC176Q06HA'].unique() #possiveis respostas

#Pergunta: Buscar informações práticas on-line (p. ex., programação de eventos,dicas, receitas).
professoresDF['TC176Q07HA'].unique() #possiveis respostas
# Out:
# array([ 4.,  5.,  3.,  2., nan,  1.])

# %%
#TC172
#Pergunta: Qual das afirmações abaixo descreve melhor o modo como você lê livros (sobre qualquer assunto)?
#Valores  possiveis a sereme respondidos:
# 1 - Nunca ou quase nunca leio livros.
# 2 - Leio com mais frequência livros em papel.
# 3 - Leio com mais frequência livros em dispositivos eletrônicos (p. ex., e-reader, tablet, celular, computador).
# 4 - Leio livros com a mesma frequência em papel e em dispositivos eletrônicos.
professoresDF['TC172Q01HA'].unique() #possiveis respostas
# Out:
# array([ 2.,  3.,  4., nan,  1.])

# %%
#TC173
#Pergunta:Qual das seguintes afirmações descreve melhor o modo como você lê notícias (p. ex., política, cultura, esporte, notícias locais)?
#Valores  possiveis a sereme respondidos:
# 1 - Não acompanho as notícias.
# 2 - Apenas assisto ou escuto as notícias (p. ex., rádio, televisão, podcasts).
# 3 - Leio notícias com mais frequência em dispositivos eletrônicos (p. ex., tablet, celular, computador).
# 4 - Leio notícias com mais frequência em papel (p. ex., jornais, revistas).
# 5 -Leio notícias com a mesma frequência em papel e em dispositivos eletrônicos.
professoresDF['TC173Q01HA'].unique() #possiveis respostas
# Out:
# array([ 2.,  4.,  5.,  3., nan,  1.])
