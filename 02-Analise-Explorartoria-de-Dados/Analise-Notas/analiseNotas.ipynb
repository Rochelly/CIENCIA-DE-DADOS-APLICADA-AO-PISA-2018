# %%
import pyreadstat  as ps 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas  as pd
import numpy as np
# %matplotlib inline

# %%
notasPath="00-Bases-de-dados/Notas-Paises/notas-paises-ptbr-corrigidos.csv"

# %%
notasDF=pd.read_csv(notasPath)

# %%
notasDF
# Out:
#     Unnamed: 0         País/Economia  Nota Média Em Ciências  \
# 0            4       B-S-J-Z (China)                     591
# 1           65             Cingapura                     569
# 2           44         Macau (China)                     558
# 3           28     Hong Kong (China)                     551
# 4           14         Taipei Chinês                     531
# ..         ...                   ...                     ...
# 73          50              Marrocos                     368
# 74          39                Kosovo                     366
# 75          55                Panamá                     353
# 76          57             Filipinas                     353
# 77          21  República Dominicana                     325
#
#     Nota Média Em Matemática  CNT
# 0                        590  CHN
# 1                        551  SGP
# 2                        544  MAC
# 3                        517  HKG
# 4                        516  TAP
# ...

# %%
sns.displot(notasDF['Nota Média Em Matemática'])

# %%
sns.displot(notasDF['Nota Média Em Ciências'])

# %%
sns.jointplot(x="Nota Média Em Ciências",y="Nota Média Em Matemática",data=notasDF,palette='coolwarm')

# %%
plt.figure(figsize=(30,10))
#sns.set_style('darkgrid')
#sns.despine()
sns.jointplot(x="Nota Média Em Ciências",y="Nota Média Em Matemática",data=notasDF,kind='hex',palette='deep')

# %%
notasDFCat=pd.read_csv('00-Bases-de-dados/Notas-Paises/Resultados.csv')

sns.set_style('darkgrid')
sns.despine()
plt.figure(figsize=(15,6))
sns.boxplot(data=notasDFCat,y="Teste",x="Notas Médias",orient='h',palette='pastel')
sns.swarmplot(data=notasDFCat,y="Teste",x="Notas Médias",orient='h',color=".25")
# Out:
# <AxesSubplot:xlabel='Notas Médias', ylabel='Teste'>
