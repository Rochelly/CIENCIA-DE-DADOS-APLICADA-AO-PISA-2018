# %% [markdown]
# # Modelagem dataset professores  com  Floresta Aleátória

# %% [markdown]
# ## Importando as Bibliotecas Necessárias

# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as pyplot
import seaborn as sns
# %matplotlib inline

from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

# %% [markdown]
# ## Carregando o dataset

# %%
pathTeach='00-Bases-de-dados/Professores- X-Niveis/pisa-professores-niveis.csv'
professoresDF =  pd.read_csv(pathTeach)
professoresDF = professoresDF.drop(['Unnamed: 0'],axis=1)

# %%
from  sklearn.model_selection  import train_test_split

# %% [markdown]
# ## Separando as variáveis x e y

# %%
x = professoresDF.drop(['CNT','nivelMatematica','nivelCiencias'],axis=1) # 
y = professoresDF['nivelCiencias'] #  seleciona somente o que se quer prever

# %%
x
# Out:
#        TC001Q01NA  TC002Q01NA  TC186Q01HA  TC005Q01NA  TC007Q01NA  TC007Q02NA  \
# 0             1.0        40.0         1.0         1.0        10.0        10.0
# 1             2.0        26.0         1.0         1.0         5.0         5.0
# 2             2.0        38.0         1.0         1.0        11.0        16.0
# 3             1.0        42.0         1.0         1.0         2.0         3.0
# 4             1.0        30.0         1.0         1.0         5.0         5.0
# ...           ...         ...         ...         ...         ...         ...
# 41682         2.0        63.0         1.0         1.0        18.0        39.0
# 41683         1.0        49.0         1.0         2.0        14.0        14.0
# 41684         1.0        42.0         1.0         1.0         6.0        17.0
# 41685         2.0        25.0         1.0         1.0         1.0         1.0
# 41686         2.0        59.0         1.0         1.0        20.0        35.0
#
# ...

# %%
y
# Out:
# 0        Alta
# 1        Alta
# 2        Alta
# 3        Alta
# 4        Alta
#          ...
# 41682    Alta
# 41683    Alta
# 41684    Alta
# 41685    Alta
# 41686    Alta
# Name: nivelCiencias, Length: 41687, dtype: object

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
dt= RandomForestClassifier()
rfe = RFE(dt)
fit = rfe.fit(x,y)
cols = fit.get_support(indices=True)
x=professoresDF.iloc[:,cols]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_18228/165486385.py in <module>
#       3 dt= RandomForestClassifier()
#       4 rfe = RFE(dt)
# ----> 5 fit = rfe.fit(x,y)
#       6 cols = fit.get_support(indices=True)
#       7 x=professoresDF.iloc[:,cols]
#
# ~/.local/lib/python3.7/site-packages/sklearn/feature_selection/_rfe.py in fit(self, X, y, **fit_params)
#     220             Fitted estimator.
#     221         """
# --> 222         return self._fit(X, y, **fit_params)
#     223
#     224     def _fit(self, X, y, step_score=None, **fit_params):
#
# ~/.local/lib/python3.7/site-packages/sklearn/feature_selection/_rfe.py in _fit(self, X, y, step_score, **fit_params)
#     281                 print("Fitting estimator with %d features." % np.sum(support_))
#     282
# --> 283             estimator.fit(X[:, features], y, **fit_params)
#     284
# ...

# %%
x
# Out:
#        TC001Q01NA  TC002Q01NA  TC186Q01HA  TC005Q01NA  TC007Q01NA  TC007Q02NA  \
# 0             1.0        40.0         1.0         1.0        10.0        10.0
# 1             2.0        26.0         1.0         1.0         5.0         5.0
# 2             2.0        38.0         1.0         1.0        11.0        16.0
# 3             1.0        42.0         1.0         1.0         2.0         3.0
# 4             1.0        30.0         1.0         1.0         5.0         5.0
# ...           ...         ...         ...         ...         ...         ...
# 41682         2.0        63.0         1.0         1.0        18.0        39.0
# 41683         1.0        49.0         1.0         2.0        14.0        14.0
# 41684         1.0        42.0         1.0         1.0         6.0        17.0
# 41685         2.0        25.0         1.0         1.0         1.0         1.0
# 41686         2.0        59.0         1.0         1.0        20.0        35.0
#
# ...

# %%
y
# Out:
# 0        Alta
# 1        Alta
# 2        Alta
# 3        Alta
# 4        Alta
#          ...
# 41682    Alta
# 41683    Alta
# 41684    Alta
# 41685    Alta
# 41686    Alta
# Name: nivelCiencias, Length: 41687, dtype: object

# %%
baseOtimProfDF = pd.DataFrame(x)

# %%
baseOtimProfDF['nivelCiencias']=  professoresDF['nivelCiencias']

# %%
baseOtimProfDF['nivelMatematica']=  professoresDF['nivelMatematica']

# %%
baseOtimProfDF
# Out:
#        TC001Q01NA  TC002Q01NA  TC186Q01HA  TC005Q01NA  TC007Q01NA  TC007Q02NA  \
# 0             1.0        40.0         1.0         1.0        10.0        10.0
# 1             2.0        26.0         1.0         1.0         5.0         5.0
# 2             2.0        38.0         1.0         1.0        11.0        16.0
# 3             1.0        42.0         1.0         1.0         2.0         3.0
# 4             1.0        30.0         1.0         1.0         5.0         5.0
# ...           ...         ...         ...         ...         ...         ...
# 41682         2.0        63.0         1.0         1.0        18.0        39.0
# 41683         1.0        49.0         1.0         2.0        14.0        14.0
# 41684         1.0        42.0         1.0         1.0         6.0        17.0
# 41685         2.0        25.0         1.0         1.0         1.0         1.0
# 41686         2.0        59.0         1.0         1.0        20.0        35.0
#
# ...

# %%
baseOtimProfDF.to_csv('00-Bases-de-dados/Professores-Otimizada-Niveis/pisa-prof-otimizada.csv')
